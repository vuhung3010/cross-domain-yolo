# %% [markdown]
# # Original YOLO-G — `--da-img`Image-level DANN only (no AdvGRL, no aux, no triplet). Reproduces the original YOLO-G method.

# %%
BASE_DIR = '/content/drive/MyDrive/yolog-advgrl'%cd /content/yolo-G

# %%
# !python train_GRL.py --weights yolov5l.pt --cfg configs/domain/yolov5l_GRL.yaml \    --data domain/city_foggycity.yaml --epochs 50 --batch-size 4 --img 640 \    --name yolog_original \    --da-img

# %%
# !python val_GRL.py --weights runs/train/yolog_original/weights/best.pt \    --data domain/city_foggycity.yaml --task val --img 640 --batch-size 8

# %% [markdown]
# # Baseline — source-only YOLOv5-LNo DA flags. Establishes the floor.

# %%
BASE_DIR = '/content/drive/MyDrive/yolog-advgrl'%cd /content/yolo-G

# %%
# !python train_GRL.py --weights yolov5l.pt --cfg configs/domain/yolov5l_GRL.yaml \    --data domain/city_foggycity.yaml --epochs 50 --batch-size 8 --img 640 \    --name baseline

# %%
# !python val_GRL.py --weights runs/train/baseline/weights/best.pt \    --data domain/city_foggycity.yaml --task val --img 640 --batch-size 8

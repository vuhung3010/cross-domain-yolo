# %% [markdown]
# # Full method — `--da-img --advgrl --aux --triplet-img`All components on. Batch-size 2 because the backbone sees source/target/aux concatenated (effective batch = 6).

# %%
BASE_DIR = '/content/drive/MyDrive/yolog-advgrl'%cd /content/yolo-G

# %%
# !python train_GRL.py --weights yolov5l.pt --cfg configs/domain/yolov5l_GRL.yaml \    --data domain/city_foggycity.yaml --epochs 50 --batch-size 2 --img 640 \    --name advgrl_full \    --da-img --advgrl --aux --triplet-img

# %%
# !python val_GRL.py --weights runs/train/advgrl_full/weights/best.pt \    --data domain/city_foggycity.yaml --task val --img 640 --batch-size 8

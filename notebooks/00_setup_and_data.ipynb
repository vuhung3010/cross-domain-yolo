# %% [markdown]
# # Setup & Data — Cityscapes + Foggy CityscapesMount Drive, clone repo, install deps, point dataset YAML at the data location.

# %%
from google.colab import drivedrive.mount('/content/drive')BASE_DIR = '/content/drive/MyDrive/yolog-advgrl'import os; os.makedirs(BASE_DIR, exist_ok=True)

# %%
# %cd /content!git clone https://github.com/<your-fork>/yolo-G.git%cd yolo-G!pip install -r requirements.txt

# %%
# Place Cityscapes (YOLO format) under {BASE_DIR}/cityscapes/ with images/{train,val_foggy,train_foggy} + labels/train!ls {BASE_DIR}/cityscapes/images || echo 'Place the dataset at {BASE_DIR}/cityscapes/ before continuing'

# %%
# Point domain/city_foggycity.yaml `path:` at the Drive dataset root.import yamlyaml_path = 'domain/city_foggycity.yaml'with open(yaml_path) as f: cfg = yaml.safe_load(f)cfg['path'] = f'{BASE_DIR}/cityscapes'with open(yaml_path, 'w') as f: yaml.safe_dump(cfg, f)print(cfg)
